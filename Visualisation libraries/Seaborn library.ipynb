# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df=sns.load_dataset('flights')
df
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   year        144 non-null    int64
#  1   month       144 non-null    category
#  2   passengers  144 non-null    int64
# dtypes: category(1), int64(2)
# memory usage: 2.9 KB

# %% [markdown]
# ### relplot()- to understand the relationships between the variables of a dataset

# %%
sns.set(style='darkgrid')
sns.relplot(x='passengers',y='year',data=df)

# %% [markdown]
# #### no of passengers kept increasing gradually

# %%
sns.relplot(x='passengers',y='year',hue='year',data=df)

# %% [markdown]
# ### lineplot- can be use by using kind='line'

# %%
sns.relplot(x='passengers',y='year',hue='year',data=df,kind='line')

# %%
df=pd.DataFrame({'Day':[1,2,3,4,5,6,7],'Grocery':[30,80,45,23,51,46,76],'Clothes':[13,40,34,23,54,67,98],'Utensils':[12,32,27,56,87,54,34]},index=[1,2,3,4,5,6,7])
df
# Out:
#    Day  Grocery  Clothes  Utensils
# 1    1       30       13        12
# 2    2       80       40        32
# 3    3       45       34        27
# 4    4       23       23        56
# 5    5       51       54        87
# 6    6       46       67        54
# 7    7       76       98        34

# %%
sns.relplot(kind='line',x='Day',y='Grocery',data=df)

# %%
sns.relplot(x='Day',y='Grocery',data=df)

# %% [markdown]
# ### Plotting with Categorical Data:
# This approach comes into the picture when our main variable is further divided into discrete groups (categorical). This can be achieved using the catplot() function.

# %%
df=sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.catplot(x='day',y='total_bill',data=df)

# %%
sns.catplot(x='day',y='total_bill',data=df,kind='bar')

# %%
sns.catplot(x='day',y='total_bill',data=df,kind='violin')

# %%
sns.catplot(x='day',y='total_bill',data=df,kind='swarm')

# %% [raw]
# Categorical scatterplots:
#
# - :func:`stripplot` (with ``kind="strip"``; the default)
# - :func:`swarmplot` (with ``kind="swarm"``)
#
# Categorical distribution plots:
#
# - :func:`boxplot` (with ``kind="box"``)
# - :func:`violinplot` (with ``kind="violin"``)
# - :func:`boxenplot` (with ``kind="boxen"``)
#
# Categorical estimate plots:
#
# - :func:`pointplot` (with ``kind="point"``)
# - :func:`barplot` (with ``kind="bar"``)
# - :func:`countplot` (with ``kind="count"``)

# %%
sns.catplot(x='day',y='total_bill',data=df,kind='point')

# %% [markdown]
# ### distplots()-Plotting Univariate distributions:

# %%
sns.distplot(df['total_bill'])
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %% [markdown]
# #### mostly people spend between 10-30

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.jointplot(x='tip',y='total_bill',data=df)

# %%
sns.jointplot(x='tip',y='total_bill',data=df,kind='kde')

# %%
sns.jointplot(x='tip',y='total_bill',data=df,kind='hist')

# %%
sns.jointplot(x='tip',y='total_bill',data=df,kind='reg')

# %%
sns.jointplot(x='tip',y='total_bill',data=df,kind='hex')

# %% [markdown]
# ### Multi-Plot Grids :- plots or graphs that are plotted using the same scale and axes to aid comparison between them

# %%
a=sns.load_dataset('iris')
a
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
b = sns.FacetGrid(a, col="species")
b.map(plt.scatter, "sepal_length",'petal_length')  #Apply a plotting function to each facet's subset of the data.

# %%
b.map(plt.hist, "sepal_length")

# %%
a=sns.FacetGrid(df,col='time')
a.map(plt.scatter,'total_bill','size')

# %% [markdown]
# #### as people are comimg in groups of generally more than 2 people so they are spending more

# %%
q= sns.load_dataset("flights")
q.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
s = sns.PairGrid(q)
s.map(plt.scatter)

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
pg=sns.PairGrid(df)
pg.map(plt.scatter)

# %% [markdown]
# #### it will take only numerical variables from datasets

# %% [markdown]
# ### boxplot:-

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.boxplot(x='day',y='tip',data=df)
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
sns.boxplot(x='day',y='total_bill',data=df)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>
